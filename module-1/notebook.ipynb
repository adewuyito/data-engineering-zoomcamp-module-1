# %%
import pandas as pd

# %%
df = pd.read_csv("data/taxi_zone_lookup.csv")

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
df.head(0).to_sql(name='taxi_zone_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# Prints the schema
# print(pd.io.sql.get_schema(df, name='taxi_zone_data', con=engine))

# %%
df.to_sql(name='taxi_zone_data', con=engine, if_exists='append', index=False)
# Out:
# 265
